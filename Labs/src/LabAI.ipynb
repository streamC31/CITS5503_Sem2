# %% [markdown]
# This tutorial based on:
# https://sagemaker-examples.readthedocs.io/en/latest/hyperparameter_tuning/xgboost_direct_marketing/hpo_xgboost_direct_marketing_sagemaker_APIs.html
#
# Modified by: Camilo Pestana

# %% [markdown]
# Objectives:
# <ul>
# <li>Be familiar with some common libraries for Data Analysis in Python such as Pandas.</li>
# <li>Get familiar with AWS SageMaker to train Machine Learning models using the cloud</li>
# <li>Get familiar with Jupyter Notebooks</li>
# </ul>

# %% [markdown]
# # Install Missing libraries in your local computer

# %%
# Install SageMaker
# !pip install sagemaker
# Install pandas
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sagemaker in /home/stream/.local/lib/python3.10/site-packages (2.232.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (3.0.0)
# Requirement already satisfied: cloudpickle==2.2.1 in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (2.2.1)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /usr/lib/python3/dist-packages (from sagemaker) (4.6.4)
# Requirement already satisfied: pyyaml~=6.0 in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (6.0.2)
# Requirement already satisfied: pathos in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (0.3.3)
# Requirement already satisfied: platformdirs in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (4.3.6)
# Requirement already satisfied: schema in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (0.7.7)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: docker in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (7.1.0)
# Requirement already satisfied: tqdm in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (4.66.5)
# Requirement already satisfied: requests in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (2.32.3)
# Requirement already satisfied: sagemaker-core<2.0.0,>=1.0.0 in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (1.0.9)
# Requirement already satisfied: pandas in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (2.2.2)
# Requirement already satisfied: psutil in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (6.0.0)
# Requirement already satisfied: jsonschema in /usr/lib/python3/dist-packages (from sagemaker) (3.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (24.1)
# Requirement already satisfied: google-pasta in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: boto3<2.0,>=1.34.142 in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (1.34.149)
# Requirement already satisfied: attrs<24,>=23.1.0 in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (23.2.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (1.26.4)
# Requirement already satisfied: protobuf<5.0,>=3.12 in /usr/lib/python3/dist-packages (from sagemaker) (3.12.4)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in /home/stream/.local/lib/python3.10/site-packages (from sagemaker) (2.2.3)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/stream/.local/lib/python3.10/site-packages (from boto3<2.0,>=1.34.142->sagemaker) (0.10.2)
# Requirement already satisfied: botocore<1.35.0,>=1.34.149 in /home/stream/.local/lib/python3.10/site-packages (from boto3<2.0,>=1.34.142->sagemaker) (1.34.149)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/lib/python3/dist-packages (from boto3<2.0,>=1.34.142->sagemaker) (0.10.0)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in /home/stream/.local/lib/python3.10/site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker) (13.9.1)
# Requirement already satisfied: mock<5.0,>4.0 in /home/stream/.local/lib/python3.10/site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker) (4.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=1.7.0 in /home/stream/.local/lib/python3.10/site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.9.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->sagemaker) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/stream/.local/lib/python3.10/site-packages (from requests->sagemaker) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->sagemaker) (2020.6.20)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from google-pasta->sagemaker) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/stream/.local/lib/python3.10/site-packages (from pandas->sagemaker) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/stream/.local/lib/python3.10/site-packages (from pandas->sagemaker) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->sagemaker) (2022.1)
# Requirement already satisfied: dill>=0.3.9 in /home/stream/.local/lib/python3.10/site-packages (from pathos->sagemaker) (0.3.9)
# Requirement already satisfied: multiprocess>=0.70.17 in /home/stream/.local/lib/python3.10/site-packages (from pathos->sagemaker) (0.70.17)
# Requirement already satisfied: ppft>=1.7.6.9 in /home/stream/.local/lib/python3.10/site-packages (from pathos->sagemaker) (1.7.6.9)
# Requirement already satisfied: pox>=0.3.5 in /home/stream/.local/lib/python3.10/site-packages (from pathos->sagemaker) (0.3.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/stream/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/stream/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/stream/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/stream/.local/lib/python3.10/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/stream/.local/lib/python3.10/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/stream/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (0.1.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/stream/.local/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/stream/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in /home/stream/.local/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/stream/.local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# # Create Role
#
# NOTE: For security purposes we won't allow students to create Roles. However, you can see below what are the steps needed to create them.
#
# 1. Login to the AWS console -> IAM -> Roles -> Create Role
#
# 2. Create an IAM role and select the "SageMaker" service
#
# 3. Give the role "AmazonSageMakerFullAccess" permission
#
# 4. Review and create the role
#
# 5. The code needs to fetch the IAM role directly when the code is executed on a local machine. The code snippet to be used is given below:
# ```
#     iam = boto3.client('iam')
#     sagemaker_role = iam.get_role(RoleName='<sagemaker-IAM-role-name>')['Role']['Arn']
#     ```
#
# A Role has been created using the steps above and you can use it for your lab.
# ```
#     iam = boto3.client('iam')
#     sagemaker_role = iam.get_role(RoleName='Role_AWS_SageMaker')['Role']['Arn']
# ```

# %% [markdown]
# You need now to create a bucket or use an existing one and create inside the folders "sagemaker/STUDENTID-hpo-xgboost-dm"

# %% [markdown]
# # Prepare SageMaker session

# %%
import sagemaker
import boto3

import numpy as np  # For matrix operations and numerical processing
import pandas as pd  # For munging tabular data
from time import gmtime, strftime
import os

region = 'ap-southeast-2'
smclient = boto3.Session().client("sagemaker")

iam = boto3.client('iam')
sagemaker_role = iam.get_role(RoleName='SageMakerRole')['Role']['Arn']

student_id = "23011392"
bucket = '23011392-cloudstorage'
prefix = f"sagemaker/{student_id}-hpo-xgboost-dm"

# %% [markdown]
# # Download Dataset

# %% [markdown]
# Please take some time to read about the data with more detail [here](https://archive.ics.uci.edu/ml/datasets/bank+marketing)
# Let’s start by downloading the direct marketing dataset from UCI’s ML Repository.
#
# You can download the dataset manually or use the commands below. These commands should work for Linux and MacOS users.

# %%
# !wget -N https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
# !unzip -o bank-additional.zip
# Out:
# --2024-10-02 07:20:25--  https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘bank-additional.zip’
#
# bank-additional.zip     [       <=>          ] 434.15K   234KB/s    in 1.9s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-10-02 07:20:28 (234 KB/s) - ‘bank-additional.zip’ saved [444572]
#
# Archive:  bank-additional.zip
#   inflating: bank-additional/.DS_Store
#   inflating: __MACOSX/bank-additional/._.DS_Store
#   inflating: bank-additional/.Rhistory
#   inflating: bank-additional/bank-additional-full.csv
#   inflating: bank-additional/bank-additional-names.txt
#   inflating: bank-additional/bank-additional.csv
#   inflating: __MACOSX/._bank-additional

# %% [markdown]
# Now lets read this into a Pandas data frame and take a look at the data.

# %%
data = pd.read_csv("./bank-additional/bank-additional-full.csv", sep=";")
pd.set_option("display.max_columns", 500)  # Make sure we can see all of the columns
pd.set_option("display.max_rows", 50)  # Keep the output on one page
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 data = pd.read_csv("./bank-additional/bank-additional-full.csv", sep=";")
#       2 pd.set_option("display.max_columns", 500)  # Make sure we can see all of the columns
#       3 pd.set_option("display.max_rows", 50)  # Keep the output on one page
#
# File ~/.virtualenvs/CITS5503_Sem2/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.virtualenvs/CITS5503_Sem2/lib/python3.10/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/.virtualenvs/CITS5503_Sem2/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1968, in TextFileReader.read(self, nrows)
#    1965     else:
#    1966         new_col_dict = col_dict
# -> 1968     df = DataFrame(
#    1969         new_col_dict,
#    1970         columns=columns,
#    1971         index=index,
#    1972         copy=not using_copy_on_write(),
#    1973     )
#    1975     self._currow += new_rows
#    1976 return df
#
# File ~/.virtualenvs/CITS5503_Sem2/lib/python3.10/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~/.virtualenvs/CITS5503_Sem2/lib/python3.10/site-packages/pandas/core/internals/construction.py:443, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     440 if columns is not None:
#     441     from pandas.core.series import Series
# --> 443     arrays = Series(data, index=columns, dtype=object)
#     444     missing = arrays.isna()
#     445     if index is None:
#     446         # GH10856
#     447         # raise ValueError if only scalars in dict
#
# File ~/.virtualenvs/CITS5503_Sem2/lib/python3.10/site-packages/pandas/core/series.py:490, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     487 name = ibase.maybe_extract_name(name, data, type(self))
#     489 if index is not None:
# --> 490     index = ensure_index(index)
#     492 if dtype is not None:
#     493     dtype = self._validate_dtype(dtype)
#
# File ~/.virtualenvs/CITS5503_Sem2/lib/python3.10/site-packages/pandas/core/indexes/base.py:7647, in ensure_index(index_like, copy)
#    7645         return MultiIndex.from_arrays(index_like)
#    7646     else:
# -> 7647         return Index(index_like, copy=copy, tupleize_cols=False)
#    7648 else:
#    7649     return Index(index_like, copy=copy)
#
# File ~/.virtualenvs/CITS5503_Sem2/lib/python3.10/site-packages/pandas/core/indexes/base.py:565, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     562         data = com.asarray_tuplesafe(data, dtype=_dtype_obj)
#     564 try:
# --> 565     arr = sanitize_array(data, None, dtype=dtype, copy=copy)
#     566 except ValueError as err:
#     567     if "index must be specified when data is not list-like" in str(err):
#
# File ~/.virtualenvs/CITS5503_Sem2/lib/python3.10/site-packages/pandas/core/construction.py:654, in sanitize_array(data, index, dtype, copy, allow_2d)
#     651     subarr = _try_cast(data, dtype, copy)
#     653 else:
# --> 654     subarr = maybe_convert_platform(data)
#     655     if subarr.dtype == object:
#     656         subarr = cast(np.ndarray, subarr)
#
# File ~/.virtualenvs/CITS5503_Sem2/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:138, in maybe_convert_platform(values)
#     136 if arr.dtype == _dtype_obj:
#     137     arr = cast(np.ndarray, arr)
# --> 138     arr = lib.maybe_convert_objects(arr)
#     140 return arr
#
# File lib.pyx:2538, in pandas._libs.lib.maybe_convert_objects()
#
# TypeError: Cannot convert numpy.ndarray to numpy.ndarray

# %% [markdown]
# Answer the following questions:
#     - Which variables are categorical?
#     - Which ones are numerical?

# %%
data["no_previous_contact"] = np.where(
    data["pdays"] == 999, 1, 0
)  # Indicator variable to capture when pdays takes a value of 999
data["not_working"] = np.where(
    np.in1d(data["job"], ["student", "retired", "unemployed"]), 1, 0
)  # Indicator for individuals not actively employed
model_data = pd.get_dummies(data)  # Convert categorical variables to sets of indicators
model_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 data["no_previous_contact"] = np.where(
# ----> 2     data["pdays"] == 999, 1, 0
#       3 )  # Indicator variable to capture when pdays takes a value of 999
#       4 data["not_working"] = np.where(
#       5     np.in1d(data["job"], ["student", "retired", "unemployed"]), 1, 0
#       6 )  # Indicator for individuals not actively employed
#       7 model_data = pd.get_dummies(data)  # Convert categorical variables to sets of indicators
#
# NameError: name 'data' is not defined

# %% [markdown]
# Let’s remove the economic features and duration from our data as they would need to be forecasted with high precision to use as inputs in future predictions.

# %%
model_data = model_data.drop(
    ["duration", "emp.var.rate", "cons.price.idx", "cons.conf.idx", "euribor3m", "nr.employed"],
    axis=1,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 model_data = model_data.drop(
#       2     ["duration", "emp.var.rate", "cons.price.idx", "cons.conf.idx", "euribor3m", "nr.employed"],
#       3     axis=1,
#       4 )
#
# NameError: name 'model_data' is not defined

# %%
model_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model_data
#
# NameError: name 'model_data' is not defined

# %% [markdown]
# # Split Data into training, validation and test

# %% [markdown]
# We’ll then split the dataset into training (70%), validation (20%), and test (10%) datasets and convert the datasets to the right format the algorithm expects. We will use training and validation datasets during training. Test dataset will be used to evaluate model performance after it is deployed to an endpoint.
#
# Amazon SageMaker’s XGBoost algorithm expects data in the libSVM or CSV data format. For this lab, we’ll stick to CSV. Note that the first column must be the target variable and the CSV should not include headers. Also, notice that although repetitive it’s easier to do this after the train|validation|test split rather than before. This avoids any misalignment issues due to random reordering.

# %%
train_data, validation_data, test_data = np.split(
    model_data.sample(frac=1, random_state=1729),
    [int(0.7 * len(model_data)), int(0.9 * len(model_data))],
)

pd.concat([train_data["y_yes"], train_data.drop(["y_no", "y_yes"], axis=1)], axis=1).to_csv(
    "train.csv", index=False, header=False
)
pd.concat(
    [validation_data["y_yes"], validation_data.drop(["y_no", "y_yes"], axis=1)], axis=1
).to_csv("validation.csv", index=False, header=False)
pd.concat([test_data["y_yes"], test_data.drop(["y_no", "y_yes"], axis=1)], axis=1).to_csv(
    "test.csv", index=False, header=False
)
# Out:
# /home/streamc/.virtualenvs/CITS5503_Sem2/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %% [markdown]
# Now we’ll copy the file to S3 for Amazon SageMaker training to pickup.

# %%
boto3.Session().resource("s3").Bucket(bucket).Object(
    os.path.join(prefix, "train/train.csv")
).upload_file("train.csv")
boto3.Session().resource("s3").Bucket(bucket).Object(
    os.path.join(prefix, "validation/validation.csv")
).upload_file("validation.csv")

# %% [markdown]
# # Setup Hyperparameter Optimization

# %%
from time import gmtime, strftime, sleep

# Names have to be unique. You will get an error if you reuse the same name
tuning_job_name = f"{student_id}-xgboost-tuningjob-01"

print(tuning_job_name)

tuning_job_config = {
    "ParameterRanges": {
        "CategoricalParameterRanges": [],
        "ContinuousParameterRanges": [
            {
                "MaxValue": "1",
                "MinValue": "0",
                "Name": "eta",
            },
            {
                "MaxValue": "10",
                "MinValue": "1",
                "Name": "min_child_weight",
            },
            {
                "MaxValue": "2",
                "MinValue": "0",
                "Name": "alpha",
            },
        ],
        "IntegerParameterRanges": [
            {
                "MaxValue": "10",
                "MinValue": "1",
                "Name": "max_depth",
            }
        ],
    },
    "ResourceLimits": {"MaxNumberOfTrainingJobs": 2, "MaxParallelTrainingJobs": 2},
    "Strategy": "Bayesian",
    "HyperParameterTuningJobObjective": {"MetricName": "validation:auc", "Type": "Maximize"},
}
# Out:
# 23011392-xgboost-tuningjob-01

# %%
from sagemaker.image_uris import retrieve
# Use XGBoost algorithm for training
training_image = retrieve(framework="xgboost", region=region, version="latest")

s3_input_train = "s3://{}/{}/train".format(bucket, prefix)
s3_input_validation = "s3://{}/{}/validation/".format(bucket, prefix)

training_job_definition = {
    "AlgorithmSpecification": {"TrainingImage": training_image, "TrainingInputMode": "File"},
    "InputDataConfig": [
        {
            "ChannelName": "train",
            "CompressionType": "None",
            "ContentType": "csv",
            "DataSource": {
                "S3DataSource": {
                    "S3DataDistributionType": "FullyReplicated",
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3_input_train,
                }
            },
        },
        {
            "ChannelName": "validation",
            "CompressionType": "None",
            "ContentType": "csv",
            "DataSource": {
                "S3DataSource": {
                    "S3DataDistributionType": "FullyReplicated",
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3_input_validation,
                }
            },
        },
    ],
    "OutputDataConfig": {"S3OutputPath": "s3://{}/{}/output".format(bucket, prefix)},
    "ResourceConfig": {"InstanceCount": 1, "InstanceType": "ml.m5.xlarge", "VolumeSizeInGB": 10},
    "RoleArn": sagemaker_role,
    "StaticHyperParameters": {
        "eval_metric": "auc",
        "num_round": "1",
        "objective": "binary:logistic",
        "rate_drop": "0.3",
        "tweedie_variance_power": "1.4",
    },
    "StoppingCondition": {"MaxRuntimeInSeconds": 43200},
}
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/streamc/.config/sagemaker/config.yaml
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from sagemaker.image_uris import retrieve
#       2 # Use XGBoost algorithm for training
# ----> 3 training_image = retrieve(framework="xgboost", region=region, version="latest")
#       5 s3_input_train = "s3://{}/{}/train".format(bucket, prefix)
#       6 s3_input_validation = "s3://{}/{}/validation/".format(bucket, prefix)
#
# NameError: name 'region' is not defined

# %% [markdown]
# Now we can launch a hyperparameter tuning job by calling create_hyper_parameter_tuning_job API. After the hyperparameter tuning job is created, we can go to SageMaker console to track the progress of the hyperparameter tuning job until it is completed.

# %% [markdown]
# While Training you can take screenshots of the jobs you just launched on SageMaker-> Training ->
# Hyperparameter tuning jobs

# %%
#Launch Hyperparameter Tuning Job
smclient.create_hyper_parameter_tuning_job(
    HyperParameterTuningJobName=tuning_job_name,
    HyperParameterTuningJobConfig=tuning_job_config,
    TrainingJobDefinition=training_job_definition,
)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[19], line 2
#       1 #Launch Hyperparameter Tuning Job
# ----> 2 smclient.create_hyper_parameter_tuning_job(
#       3     HyperParameterTuningJobName=tuning_job_name,
#       4     HyperParameterTuningJobConfig=tuning_job_config,
#       5     TrainingJobDefinition=training_job_definition,
#       6 )
#
# File ~/.virtualenvs/CITS5503_Sem2/lib/python3.10/site-packages/botocore/client.py:569, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     565     raise TypeError(
#     566         f"{py_operation_name}() only accepts keyword arguments."
#     567     )
#     568 # The "self" in this scope is referring to the BaseClient.
# --> 569 return self._make_api_call(operation_name, kwargs)
#
# File ~/.virtualenvs/CITS5503_Sem2/lib/python3.10/site-packages/botocore/client.py:1023, in BaseClient._make_api_call(self, operation_name, api_params)
#    1019     error_code = error_info.get("QueryErrorCode") or error_info.get(
#    1020         "Code"
#    1021     )
#    1022     error_class = self.exceptions.from_code(error_code)
# -> 1023     raise error_class(parsed_response, operation_name)
#    1024 else:
#    1025     return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the CreateHyperParameterTuningJob operation: No S3 objects found under S3 URL "s3://23011392-cloudstorage/sagemaker/23011392-hpo-xgboost-dm/train" given in input data source. Please ensure that the bucket exists in the selected region (ap-southeast-2), that objects exist under that S3 prefix, and that the role "arn:aws:iam::489389878001:role/SageMakerRole" has "s3:ListBucket" permissions on bucket "23011392-cloudstorage". Error message from S3: The bucket you are attempting to access must be addressed using the specified endpoint. Please send all future requests to this endpoint.

# %% [markdown]
# Plese follow the steps from the following link and take screenshots to demonstrate you successfully completed your lab.
# [How to monitor the progress of a job?](https://docs.aws.amazon.com/sagemaker/latest/dg/automatic-model-tuning-monitor.html)

# %% [markdown]
# You should also be able to check the output in s3://YOUR_BUCKET/sagemaker/STUDENTID-hpo-xgboost-dm/output.

# %% [markdown]
# # End of Lab
#
#
# 1. In this lab we first used jupyter notebooks and pandas to explore a dataset.
# 2. Then we have learnt how to use boto3 and sagemaker to create training and hyperparameter optimization jobs, two important steps in every machine learning project.
# 3. After a job is learned SageMaker allows to deploy models in EC2 instances. However, this is out of the scope for this lab.
#
# NOTE: Don't forget to remove all resources you used such as the bucket and data generated in S3.
